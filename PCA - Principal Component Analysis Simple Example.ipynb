# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(data=iris['data'], columns=iris['feature_names'])

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2) # We want to reduce the number of features to 2
principal_components = pca.fit_transform(df)

# %%
import matplotlib.pyplot as plt

plt.scatter(principal_components[:, 0], principal_components[:, 1], c=iris['target'])
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.show()

# %%
# Fit PCA to the data
pca = PCA(n_components=2)
principal_components = pca.fit_transform(df)

# Get the feature importances
feature_importances = pca.components_.T

# Print the feature importances
print('Feature Importances:\n', feature_importances)
# Out:
# Feature Importances:
#  [[ 0.36138659  0.65658877]
#  [-0.08452251  0.73016143]
#  [ 0.85667061 -0.17337266]
#  [ 0.3582892  -0.07548102]]

# %% [markdown]
# ### If a value is close to 0, the corresponding feature is not very important for that principal component.
# ### If a value is positive and large, the corresponding feature is positively correlated with that principal component.
# ### If a value is negative and large, the corresponding feature is negatively correlated with that principal component.
